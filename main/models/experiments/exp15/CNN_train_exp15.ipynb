# %% [markdown]
# # 1. Configuration

# %%
import os
import gc
import cv2
import copy
import random
import numpy as np
import pandas as pd
from pathlib import Path
import typing as tp
from io import BytesIO
from PIL import Image
import h5py
import timm
from time import time
from tqdm.notebook import tqdm
import shutil

import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedGroupKFold

import torch
import torchvision
from torch import nn
from torch import optim
from torch.optim import lr_scheduler
from torch.cuda import amp
from torch.utils.data import Dataset
import torch.nn.functional as F
import albumentations as A
from albumentations.pytorch import ToTensorV2

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
class CFG:
    
    exp = 15
    
    is_kaggle = False
    if is_kaggle:
        OUTPUT_DIR = Path('/kaggle/input/isic2024-baseline')
        TRAIN_DIR = Path('/kaggle/input/isic-2024-challenge/train-image/image')
        TRAIN_HDF5 = Path('/kaggle/input/isic-2024-challenge/train-image.hdf5')
        TEST_HDF5 = Path('/kaggle/input/isic-2024-challenge/test-image.hdf5')
        TRAIN_META = Path('/kaggle/input/isic-2024-challenge/train-metadata.csv')
        TEST_META = Path('/kaggle/input/isic-2024-challenge/test-metadata.csv')
        SAMPLE_SUB = Path('/kaggle/input/isic-2024-challenge/sample_submission.csv')
        PRETRAINED_MODEL = ''
        
    else:
        OUTPUT_DIR = Path(f'/root/Development/Kaggle/ISIC2024/main/models/experiments/exp{exp}/outputs')
        OUTPUT_LOG = Path(f'/root/Development/Kaggle/ISIC2024/main/models/experiments/exp{exp}/log.txt')
        TRAIN_DIR = Path('/root/Development/Kaggle/ISIC2024/data/raw/train-image/image')
        TRAIN_HDF5 = Path('/root/Development/Kaggle/ISIC2024/data/raw/train-image.hdf5')
        TEST_HDF5 = Path('/root/Development/Kaggle/ISIC2024/data/raw/test-image.hdf5')
        TRAIN_META = Path('/root/Development/Kaggle/ISIC2024/data/raw/train-metadata.csv')
        TEST_META = Path('/root/Development/Kaggle/ISIC2024/data/raw/test-metadata.csv')
        SAMPLE_SUB = Path('/root/Development/Kaggle/ISIC2024/data/raw/sample_submission.csv')
        TRAIN_META_ADD = Path('/root/Development/Kaggle/ISIC2024/data/external/All/metadata.csv')
        TRAIN_HDF5_ADD = Path('/root/Development/Kaggle/ISIC2024/data/external/All/image.hdf5')
        TRAIN_HDF5_COMBINED = Path('/root/Development/Kaggle/ISIC2024/data/processed/train-image-combined.hdf5')
        PRETRAINED_MODEL = ''
        # PRETRAINED_MODEL = Path('/root/Development/Kaggle/ISIC2024/main/models/experiments/exp10/outputs/averaged_model.pth')
        
    
        
    max_epoch = 9
    n_folds = 5
    n_classes = 2
    random_seed = 42
    deterministic = True
    enable_amp = True
    view = True
    
    model_name = 'tf_efficientnet_b3.ns_jft_in1k'
    output_dim_models = {
        "resnet18.a1_in1k": 512,
        "efficientnet_b0.ra_in1k": 320,
        "tf_efficientnet_b0.ns_jft_in1k": 1280,
        # 'tf_efficientnet_b5.ns_jft_in1k': 1280,
        'tf_efficientnet_b3.ns_jft_in1k': 1536,
    }
    pretrained = True
    img_size = 224
    # img_size = 384
    interpolation = cv2.INTER_LINEAR
    es_patience = 5 
    batch_size = 128
    lr = 1.0e-03
    weight_decay = 1.0e-02 # default
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"

# %%
train_meta = pd.read_csv(CFG.TRAIN_META)
train_meta_add = pd.read_csv(CFG.TRAIN_META_ADD)
test_meta = pd.read_csv(CFG.TEST_META)
print(len(train_meta))
print(len(train_meta_add))
print(len(test_meta))

# head
display(train_meta[train_meta['target'] > 0.5].head(10))
display(train_meta.head())
display(train_meta_add.head())
display(test_meta.head())
# Out:
# /tmp/ipykernel_1072003/90390972.py:1: DtypeWarning: Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_meta = pd.read_csv(CFG.TRAIN_META)
# 401059
# 81722
# 3
# /tmp/ipykernel_1072003/90390972.py:2: DtypeWarning: Columns (8,13,16,17,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_meta_add = pd.read_csv(CFG.TRAIN_META_ADD)
#            isic_id  target  patient_id  age_approx     sex  \
# 387   ISIC_0082829       1  IP_3249371        80.0  female
# 935   ISIC_0096034       1  IP_6723298        75.0    male
# 1245  ISIC_0104229       1  IP_9057861        80.0    male
# 1846  ISIC_0119495       1  IP_6856511        60.0    male
# 3478  ISIC_0157834       1  IP_3927284        55.0    male
# 4812  ISIC_0190307       1  IP_4890448        65.0    male
# 5673  ISIC_0211092       1  IP_2203964        65.0    male
# 6057  ISIC_0220459       1  IP_7346729        65.0    male
# 6741  ISIC_0238218       1  IP_6356898        55.0    male
# 8204  ISIC_0275647       1  IP_7411721        45.0    male
#
#      anatom_site_general  clin_size_long_diam_mm          image_type  \
# 387       anterior torso                    9.27  TBP tile: close-up
# 935            head/neck                    3.88  TBP tile: close-up
# 1245      anterior torso                    6.55  TBP tile: close-up
# 1846     upper extremity                    5.27  TBP tile: close-up
# 3478     posterior torso                    5.29  TBP tile: close-up
# 4812           head/neck                    6.10  TBP tile: close-up
# 5673     posterior torso                    2.52  TBP tile: close-up
# 6057     upper extremity                    5.54  TBP tile: close-up
# 6741           head/neck                    1.45  TBP tile: close-up
# 8204     posterior torso                    5.62  TBP tile: close-up
#
#      tbp_tile_type   tbp_lv_A  tbp_lv_Aext   tbp_lv_B  tbp_lv_Bext   tbp_lv_C  \
# 387         3D: XP  18.093368    13.054772  19.090458    21.211776  26.302386
# 935      3D: white  26.187010    21.394010  25.553420    24.914770  36.588750
# 1245     3D: white  33.480140    24.249430  26.160100    25.295430  42.488470
# 1846     3D: white  25.872050    20.194650  26.805590    28.459890  37.254570
# 3478     3D: white  30.966662    22.008635  24.066940    26.734379  39.219278
# 4812        3D: XP  36.467641    29.423119  31.796962    30.345482  48.383216
# 5673     3D: white  18.735590    15.644417  22.391089    24.595729  29.195602
# 6057        3D: XP  19.577950    15.365890  26.696370    29.166740  33.105780
# 6741        3D: XP  16.645950    15.078960  18.609470    17.983900  24.967980
# 8204        3D: XP  23.281400    15.250300  34.395250    30.973160  41.533800
#
#       tbp_lv_Cext   tbp_lv_H  tbp_lv_Hext   tbp_lv_L  tbp_lv_Lext  \
# 387     24.907158  46.536028    58.389811  23.395088    34.784341
# 935     32.839750  44.298420    49.347720  49.373060    57.114240
# 1245    35.041320  38.002700    46.209460  50.728930    58.546240
# 1846    34.896840  46.015270    54.641140  56.674930    64.638890
# 3478    34.628125  37.853948    50.537646  55.210012    66.135030
# 4812    42.267816  41.085910    45.884132  43.274921    50.995427
# 5673    29.149574  50.079323    57.541096  30.879498    38.828701
# 6057    32.966790  53.745310    62.218440  32.182520    42.584540
# 6741    23.469040  48.187740    50.021180  19.478640    23.909070
# 8204    34.524030  55.906780    63.785690  42.537180    53.811090
#
#       tbp_lv_areaMM2  tbp_lv_area_perim_ratio  tbp_lv_color_std_mean  \
# 387        40.964534                25.940259               3.287692
# 935         6.192531                30.648580               0.624458
# 1245       12.103580                38.025960               1.401430
# 1846       13.267030                30.444160               1.472167
# 3478       15.049728                24.313243               2.243673
# 4812       16.382060                33.381599               1.394804
# 5673        3.978232                14.943015               0.624906
# 6057       20.435350                16.172750               1.210843
# 6741        1.388628                12.961830               0.000000
# 8204       18.877840                15.949350               1.610736
#
#       tbp_lv_deltaA  tbp_lv_deltaB  tbp_lv_deltaL  tbp_lv_deltaLB  \
# 387        5.038595      -2.121318     -11.389253       11.836020
# 935        4.793001       0.638651      -7.741185        8.023705
# 1245       9.230707       0.864665      -7.817310        8.023790
# 1846       5.677403      -1.654301      -7.963960        8.284219
# 3478       8.958027      -2.667440     -10.925018       11.522597
# 4812       7.044522       1.451480      -7.720506        8.032787
# 5673       3.091173      -2.204640      -7.949203        8.338908
# 6057       4.212066      -2.470366     -10.402020       10.823980
# 6741       1.566990       0.625565      -4.430426        4.601969
# 8204       8.031106       3.422084     -11.273910       11.885800
#
#       tbp_lv_deltaLBnorm  tbp_lv_eccentricity       tbp_lv_location  \
# 387            12.342322             0.763841  Torso Front Top Half
# 935             5.716512             0.672715           Head & Neck
# 1245            5.621653             0.907116  Torso Front Top Half
# 1846            5.481429             0.745061     Right Arm - Upper
# 3478            7.399501             0.690814  Torso Back Top Third
# 4812            6.005603             0.604848           Head & Neck
# 5673            8.333859             0.587364  Torso Back Top Third
# 6057            9.881978             0.511094     Right Arm - Upper
# 6741            5.882772             0.651130           Head & Neck
# 8204            9.247455             0.647750  Torso Back Top Third
#
#      tbp_lv_location_simple  tbp_lv_minorAxisMM  tbp_lv_nevi_confidence  \
# 387             Torso Front            6.677133            1.597228e-02
# 935             Head & Neck            2.710643            9.713997e-04
# 1245            Torso Front            3.481341            1.629116e-12
# 1846              Right Arm            3.573096            1.106073e+00
# 3478             Torso Back            4.222128            2.115099e-02
# 4812            Head & Neck            4.939606            1.095004e-01
# 5673             Torso Back            2.034143            7.786863e+01
# 6057              Right Arm            4.569056            8.773333e+01
# 6741            Head & Neck            1.065503            1.995397e+01
# 8204             Torso Back            4.246575            9.848039e+01
#
#       tbp_lv_norm_border  tbp_lv_norm_color  tbp_lv_perimeterMM  \
# 387             5.936484           9.830578           32.598015
# 935             7.567831           1.757932           13.776510
# 1245            8.688260           4.108186           21.453450
# 1846            6.435350           3.850777           20.097350
# 3478            5.267599           7.734870           19.128714
# 4812            7.729336           4.770095           23.385024
# 5673            2.132171           1.958223            7.710174
# 6057            1.395407           4.025040           18.179540
# 6741            2.092345           0.000000            4.242543
# 8204            2.348067           4.611225           17.351920
#
#       tbp_lv_radial_color_std_max  tbp_lv_stdL  tbp_lv_stdLExt  \
# 387                      3.514434     5.464301        2.717044
# 935                      0.549971     1.604156        2.798056
# 1245                     1.340916     1.539307        3.697858
# 1846                     1.104453     2.575811        2.600541
# 3478                     2.904396     4.122797        3.134399
# 4812                     1.780440     1.838077        2.773380
# 5673                     0.680611     2.460653        1.549486
# 6057                     1.469755     2.873449        1.812626
# 6741                     0.000000     1.525839        1.487442
# 8204                     1.468856     3.281537        1.826447
#
#       tbp_lv_symm_2axis  tbp_lv_symm_2axis_angle    tbp_lv_x     tbp_lv_y  \
# 387            0.472358                        0   61.956005  1180.003540
# 935            0.576744                       15   54.423520  1675.860000
# 1245           0.546485                      155   84.834820  1441.758000
# 1846           0.428889                      160  293.127500  1425.201000
# 3478           0.422091                       65 -128.599152  1481.198364
# 4812           0.531303                       65  -57.239716  1601.575562
# 5673           0.229358                       25 -159.278320  1388.832764
# 6057           0.099638                       90  419.665200  1254.211000
# 6741           0.272727                       35   34.440430  1592.288000
# 8204           0.233743                       75    6.216828  1367.378000
#
#         tbp_lv_z                                        attribution  \
# 387   -77.904053  Department of Dermatology, Hospital Clínic de ...
# 935   -37.749880             Memorial Sloan Kettering Cancer Center
# 1245  -60.321040             Memorial Sloan Kettering Cancer Center
# 1846   50.789730             Memorial Sloan Kettering Cancer Center
# 3478   13.294312             Memorial Sloan Kettering Cancer Center
# 4812  -37.050232  Frazer Institute, The University of Queensland...
# 5673  -82.282639  Frazer Institute, The University of Queensland...
# 6057   60.192440  Department of Dermatology, Hospital Clínic de ...
# 6741   29.257570  Department of Dermatology, Hospital Clínic de ...
# 8204  220.518600                                         ACEMID MIA
#
#      copyright_license   lesion_id  \
# 387           CC-BY-NC  IL_7881385
# 935              CC-BY  IL_5240575
# 1245             CC-BY  IL_1702337
# 1846             CC-BY  IL_3266850
# 3478             CC-BY  IL_2429082
# 4812             CC-BY  IL_3603982
# 5673             CC-BY  IL_4594949
# 6057          CC-BY-NC  IL_8860946
# 6741          CC-BY-NC  IL_7253381
# 8204              CC-0  IL_5004024
#
#                                               iddx_full     iddx_1  \
# 387   Malignant::Malignant epidermal proliferations:...  Malignant
# 935   Malignant::Malignant adnexal epithelial prolif...  Malignant
# 1245  Malignant::Malignant adnexal epithelial prolif...  Malignant
# 1846  Malignant::Malignant epidermal proliferations:...  Malignant
# 3478  Malignant::Malignant adnexal epithelial prolif...  Malignant
# 4812  Malignant::Malignant adnexal epithelial prolif...  Malignant
# 5673  Malignant::Malignant adnexal epithelial prolif...  Malignant
# 6057  Malignant::Malignant melanocytic proliferation...  Malignant
# 6741  Malignant::Malignant adnexal epithelial prolif...  Malignant
# 8204  Malignant::Malignant melanocytic proliferation...  Malignant
#
#                                                  iddx_2  \
# 387                  Malignant epidermal proliferations
# 935   Malignant adnexal epithelial proliferations - ...
# 1245  Malignant adnexal epithelial proliferations - ...
# 1846                 Malignant epidermal proliferations
# 3478  Malignant adnexal epithelial proliferations - ...
# 4812  Malignant adnexal epithelial proliferations - ...
# 5673  Malignant adnexal epithelial proliferations - ...
# 6057    Malignant melanocytic proliferations (Melanoma)
# 6741  Malignant adnexal epithelial proliferations - ...
# 8204    Malignant melanocytic proliferations (Melanoma)
#
#                                  iddx_3                             iddx_4  \
# 387     Squamous cell carcinoma in situ                                NaN
# 935                Basal cell carcinoma      Basal cell carcinoma, Nodular
# 1245               Basal cell carcinoma      Basal cell carcinoma, Nodular
# 1846  Squamous cell carcinoma, Invasive                                NaN
# 3478               Basal cell carcinoma  Basal cell carcinoma, Superficial
# 4812               Basal cell carcinoma      Basal cell carcinoma, Nodular
# 5673               Basal cell carcinoma      Basal cell carcinoma, Nodular
# 6057                   Melanoma in situ                                NaN
# 6741               Basal cell carcinoma  Basal cell carcinoma, Superficial
# 8204                   Melanoma in situ                                NaN
#
#      iddx_5 mel_mitotic_index  mel_thick_mm  tbp_lv_dnn_lesion_confidence
# 387     NaN               NaN           NaN                     72.211683
# 935     NaN               NaN           NaN                     94.559590
# 1245    NaN               NaN           NaN                     66.196170
# 1846    NaN               NaN           NaN                     99.991270
# 3478    NaN               NaN           NaN                     99.960846
# 4812    NaN               NaN           NaN                     95.272583
# 5673    NaN               NaN           NaN                     99.999869
# 6057    NaN               NaN           NaN                     99.999020
# 6741    NaN               NaN           NaN                     99.914940
# 8204    NaN               NaN           NaN                    100.000000
#         isic_id  target  patient_id  age_approx   sex anatom_site_general  \
# 0  ISIC_0015670       0  IP_1235828        60.0  male     lower extremity
# 1  ISIC_0015845       0  IP_8170065        60.0  male           head/neck
# 2  ISIC_0015864       0  IP_6724798        60.0  male     posterior torso
# 3  ISIC_0015902       0  IP_4111386        65.0  male      anterior torso
# 4  ISIC_0024200       0  IP_8313778        55.0  male      anterior torso
#
#    clin_size_long_diam_mm          image_type tbp_tile_type   tbp_lv_A  \
# 0                    3.04  TBP tile: close-up     3D: white  20.244422
# 1                    1.10  TBP tile: close-up     3D: white  31.712570
# 2                    3.40  TBP tile: close-up        3D: XP  22.575830
# 3                    3.22  TBP tile: close-up        3D: XP  14.242329
# 4                    2.73  TBP tile: close-up     3D: white  24.725520
#
#    tbp_lv_Aext   tbp_lv_B  tbp_lv_Bext   tbp_lv_C  tbp_lv_Cext   tbp_lv_H  \
# 0    16.261975  26.922447    23.954773  33.684638    28.953117  53.058545
# 1    25.364740  26.331000    24.549290  41.219030    35.299260  39.702910
# 2    17.128170  37.970460    33.485410  44.174920    37.611800  59.265850
# 3    12.164757  21.448144    21.121356  25.746200    24.374023  56.414429
# 4    20.057470  26.464900    25.710460  36.217980    32.608740  46.946070
#
#    tbp_lv_Hext   tbp_lv_L  tbp_lv_Lext  tbp_lv_areaMM2  \
# 0    55.828924  54.367448    62.025701        3.152561
# 1    44.064040  48.861520    55.362360        0.919497
# 2    62.909730  53.961180    61.670520        3.265153
# 3    60.060388  18.649518    23.314841        6.079940
# 4    52.041180  46.276310    54.855740        2.101708
#
#    tbp_lv_area_perim_ratio  tbp_lv_color_std_mean  tbp_lv_deltaA  \
# 0                27.476170                0.00000       3.982447
# 1                12.235290                0.00000       6.347830
# 2                24.184620                0.00000       5.447655
# 3                14.889242                0.51452       2.077572
# 4                19.902560                0.00000       4.668053
#
#    tbp_lv_deltaB  tbp_lv_deltaL  tbp_lv_deltaLB  tbp_lv_deltaLBnorm  \
# 0       2.967674      -7.658253        8.360566            5.784302
# 1       1.781713      -6.500838        6.839008            4.987244
# 2       4.485044      -7.709336        9.092376            6.290359
# 3       0.326788      -4.665323        4.783413            6.400196
# 4       0.754434      -8.579431        9.148495            6.531302
#
#    tbp_lv_eccentricity       tbp_lv_location tbp_lv_location_simple  \
# 0             0.901302     Right Leg - Upper              Right Leg
# 1             0.639885           Head & Neck            Head & Neck
# 2             0.932147  Torso Back Top Third             Torso Back
# 3             0.654458  Torso Front Top Half            Torso Front
# 4             0.946448  Torso Front Top Half            Torso Front
#
#    tbp_lv_minorAxisMM  tbp_lv_nevi_confidence  tbp_lv_norm_border  \
# 0            1.543016            2.628592e-03            7.091360
# 1            0.821918            1.334303e-07            2.116402
# 2            1.194905            2.959177e-04            4.798335
# 3            2.481328            2.198945e+01            1.975874
# 4            0.929916            1.378832e-03            3.658854
#
#    tbp_lv_norm_color  tbp_lv_perimeterMM  tbp_lv_radial_color_std_max  \
# 0           0.000000            9.307003                      0.00000
# 1           0.000000            3.354148                      0.00000
# 2           0.000000            8.886309                      0.00000
# 3           1.771705            9.514499                      0.66469
# 4           0.000000            6.467562                      0.00000
#
#    tbp_lv_stdL  tbp_lv_stdLExt  tbp_lv_symm_2axis  tbp_lv_symm_2axis_angle  \
# 0     2.036195        2.637780           0.590476                       85
# 1     0.853227        3.912844           0.285714                       55
# 2     1.743651        1.950777           0.361905                      105
# 3     1.258541        1.573733           0.209581                      130
# 4     2.085409        2.480509           0.313433                       20
#
#      tbp_lv_x     tbp_lv_y    tbp_lv_z  \
# 0 -182.703552   613.493652  -42.427948
# 1   -0.078308  1575.687000   57.174500
# 2  123.649700  1472.010000  232.908900
# 3 -141.024780  1442.185791   58.359802
# 4  -72.315640  1488.720000   21.428960
#
#                               attribution copyright_license   lesion_id  \
# 0  Memorial Sloan Kettering Cancer Center             CC-BY         NaN
# 1  Memorial Sloan Kettering Cancer Center             CC-BY  IL_6727506
# 2  Memorial Sloan Kettering Cancer Center             CC-BY         NaN
# 3                              ACEMID MIA              CC-0         NaN
# 4  Memorial Sloan Kettering Cancer Center             CC-BY         NaN
#
#   iddx_full  iddx_1 iddx_2 iddx_3 iddx_4 iddx_5 mel_mitotic_index  \
# 0    Benign  Benign    NaN    NaN    NaN    NaN               NaN
# 1    Benign  Benign    NaN    NaN    NaN    NaN               NaN
# 2    Benign  Benign    NaN    NaN    NaN    NaN               NaN
# 3    Benign  Benign    NaN    NaN    NaN    NaN               NaN
# 4    Benign  Benign    NaN    NaN    NaN    NaN               NaN
#
#    mel_thick_mm  tbp_lv_dnn_lesion_confidence
# 0           NaN                     97.517282
# 1           NaN                      3.141455
# 2           NaN                     99.804040
# 3           NaN                     99.989998
# 4           NaN                     70.442510
#         isic_id                             attribution copyright_license  \
# 0  ISIC_7559201  Memorial Sloan Kettering Cancer Center             CC-BY
# 1  ISIC_0485014  Memorial Sloan Kettering Cancer Center             CC-BY
# 2  ISIC_5257439  Memorial Sloan Kettering Cancer Center             CC-BY
# 3  ISIC_2989732  Memorial Sloan Kettering Cancer Center             CC-BY
# 4  ISIC_5638210  Memorial Sloan Kettering Cancer Center             CC-BY
#
#    acquisition_day  age_approx anatom_site_general benign_malignant  \
# 0           2497.0        55.0      anterior torso           benign
# 1              1.0        45.0     lower extremity           benign
# 2           2360.0        40.0       lateral torso           benign
# 3             78.0        80.0      anterior torso           benign
# 4             78.0        80.0      anterior torso           benign
#
#    clin_size_long_diam_mm concomitant_biopsy       dermoscopic_type diagnosis  \
# 0                     6.6                NaN  contact non-polarized     nevus
# 1                     NaN                NaN  contact non-polarized       NaN
# 2                     4.2                NaN                    NaN     nevus
# 3                     NaN                NaN  non-contact polarized       NaN
# 4                     NaN                NaN  contact non-polarized       NaN
#
#   diagnosis_confirm_type family_hx_mm fitzpatrick_skin_type  \
# 0         histopathology         True                    IV
# 1                    NaN         True                     I
# 2         histopathology         True                    II
# 3                    NaN        False                    II
# 4                    NaN        False                    II
#
#            image_type   lesion_id mel_class mel_mitotic_index  mel_thick_mm  \
# 0         dermoscopic  IL_2668505       NaN               NaN           NaN
# 1         dermoscopic  IL_2775050       NaN               NaN           NaN
# 2  clinical: close-up  IL_8547824       NaN               NaN           NaN
# 3         dermoscopic  IL_4657752       NaN               NaN           NaN
# 4         dermoscopic  IL_4657752       NaN               NaN           NaN
#
#   mel_type mel_ulcer melanocytic nevus_type  patient_id personal_hx_mm  \
# 0      NaN       NaN        True        NaN  IP_1238256           True
# 1      NaN       NaN        True        NaN  IP_3227071            NaN
# 2      NaN       NaN        True        NaN  IP_7407753           True
# 3      NaN       NaN        True        NaN  IP_2597637            NaN
# 4      NaN       NaN        True        NaN  IP_2597637            NaN
#
#    pixels_x  pixels_y     sex
# 0      3264      2448  female
# 1      6000      4000  female
# 2      3264      2448  female
# 3      6000      4000    male
# 4      6000      4000    male
#         isic_id  patient_id  age_approx     sex anatom_site_general  \
# 0  ISIC_0015657  IP_6074337        45.0    male     posterior torso
# 1  ISIC_0015729  IP_1664139        35.0  female     lower extremity
# 2  ISIC_0015740  IP_7142616        65.0    male     posterior torso
#
#    clin_size_long_diam_mm          image_type tbp_tile_type  tbp_lv_A  \
# 0                    2.70  TBP tile: close-up        3D: XP  22.80433
# 1                    2.52  TBP tile: close-up        3D: XP  16.64867
# 2                    3.16  TBP tile: close-up        3D: XP  24.25384
#
#    tbp_lv_Aext  tbp_lv_B  tbp_lv_Bext   tbp_lv_C  tbp_lv_Cext   tbp_lv_H  \
# 0    20.007270  28.38412    27.043640  36.410100    33.640000  51.220960
# 1     9.657964  31.31752    27.524318  35.467806    29.169579  62.004494
# 2    19.937380  30.46368    28.384240  38.939500    34.686660  51.474730
#
#    tbp_lv_Hext  tbp_lv_L  tbp_lv_Lext  tbp_lv_areaMM2  \
# 0    53.505430  24.97985    31.114600        3.846876
# 1    70.664619  59.90409    68.141071        2.120473
# 2    54.915410  35.81945    41.358640        3.396510
#
#    tbp_lv_area_perim_ratio  tbp_lv_color_std_mean  tbp_lv_deltaA  \
# 0                22.907010               0.461149       2.797056
# 1                18.957821               0.000000       6.990705
# 2                19.464400               0.251236       4.316465
#
#    tbp_lv_deltaB  tbp_lv_deltaL  tbp_lv_deltaLB  tbp_lv_deltaLBnorm  \
# 0       1.340481      -6.134747        6.436557            6.843057
# 1       3.793202      -8.236981        9.151127            6.083388
# 2       2.079433      -5.539191        6.041092            5.446997
#
#    tbp_lv_eccentricity       tbp_lv_location tbp_lv_location_simple  \
# 0             0.664465  Torso Back Top Third             Torso Back
# 1             0.926698      Left Leg - Upper               Left Leg
# 2             0.894776  Torso Back Top Third             Torso Back
#
#    tbp_lv_minorAxisMM  tbp_lv_nevi_confidence  tbp_lv_norm_border  \
# 0            2.187644            1.698104e-02            5.435366
# 1            1.032666            2.107364e-01            4.322201
# 2            1.520786            8.052259e-13            3.968912
#
#    tbp_lv_norm_color  tbp_lv_perimeterMM  tbp_lv_radial_color_std_max  \
# 0           1.143374            9.387248                     0.304827
# 1           0.000000            6.340311                     0.000000
# 2           0.721739            8.130868                     0.230742
#
#    tbp_lv_stdL  tbp_lv_stdLExt  tbp_lv_symm_2axis  tbp_lv_symm_2axis_angle  \
# 0     1.281532        2.299935           0.479339                       20
# 1     1.271940        2.011223           0.426230                       25
# 2     1.080308        2.705857           0.366071                      110
#
#     tbp_lv_x     tbp_lv_y    tbp_lv_z  \
# 0 -155.06510  1511.222000  113.980100
# 1 -112.36924   629.535889  -15.019287
# 2  -84.29282  1303.978000  -28.576050
#
#                                          attribution copyright_license
# 0             Memorial Sloan Kettering Cancer Center             CC-BY
# 1  Frazer Institute, The University of Queensland...             CC-BY
# 2                                        FNQH Cairns             CC-BY

# %% [markdown]
# # 2. Preprocessing

# %% [markdown]
# ### process additional data

# %%
# only benign or maligant
train_meta_add = train_meta_add[train_meta_add['benign_malignant'].isin(['benign', 'malignant'])]
# make the target column
train_meta_add['target'] = train_meta_add['benign_malignant'].apply(lambda x: 1 if x == 'malignant' else 0)
# assign difference patientid
train_meta_add['patient_id'] = [
    f"example_{i+1}" if pd.isna(id) else id
    for i, id in enumerate(train_meta_add['patient_id'])
]

train_meta_add['additional'] = 1

display(train_meta_add.head())
# Out:
#         isic_id                             attribution copyright_license  \
# 0  ISIC_7559201  Memorial Sloan Kettering Cancer Center             CC-BY
# 1  ISIC_0485014  Memorial Sloan Kettering Cancer Center             CC-BY
# 2  ISIC_5257439  Memorial Sloan Kettering Cancer Center             CC-BY
# 3  ISIC_2989732  Memorial Sloan Kettering Cancer Center             CC-BY
# 4  ISIC_5638210  Memorial Sloan Kettering Cancer Center             CC-BY
#
#    acquisition_day  age_approx anatom_site_general benign_malignant  \
# 0           2497.0        55.0      anterior torso           benign
# 1              1.0        45.0     lower extremity           benign
# 2           2360.0        40.0       lateral torso           benign
# 3             78.0        80.0      anterior torso           benign
# 4             78.0        80.0      anterior torso           benign
#
#    clin_size_long_diam_mm concomitant_biopsy       dermoscopic_type diagnosis  \
# 0                     6.6                NaN  contact non-polarized     nevus
# 1                     NaN                NaN  contact non-polarized       NaN
# 2                     4.2                NaN                    NaN     nevus
# 3                     NaN                NaN  non-contact polarized       NaN
# 4                     NaN                NaN  contact non-polarized       NaN
#
#   diagnosis_confirm_type family_hx_mm fitzpatrick_skin_type  \
# 0         histopathology         True                    IV
# 1                    NaN         True                     I
# 2         histopathology         True                    II
# 3                    NaN        False                    II
# 4                    NaN        False                    II
#
#            image_type   lesion_id mel_class mel_mitotic_index  mel_thick_mm  \
# 0         dermoscopic  IL_2668505       NaN               NaN           NaN
# 1         dermoscopic  IL_2775050       NaN               NaN           NaN
# 2  clinical: close-up  IL_8547824       NaN               NaN           NaN
# 3         dermoscopic  IL_4657752       NaN               NaN           NaN
# 4         dermoscopic  IL_4657752       NaN               NaN           NaN
#
#   mel_type mel_ulcer melanocytic nevus_type  patient_id personal_hx_mm  \
# 0      NaN       NaN        True        NaN  IP_1238256           True
# 1      NaN       NaN        True        NaN  IP_3227071            NaN
# 2      NaN       NaN        True        NaN  IP_7407753           True
# 3      NaN       NaN        True        NaN  IP_2597637            NaN
# 4      NaN       NaN        True        NaN  IP_2597637            NaN
#
#    pixels_x  pixels_y     sex  target  additional
# 0      3264      2448  female       0           1
# 1      6000      4000  female       0           1
# 2      3264      2448  female       0           1
# 3      6000      4000    male       0           1
# 4      6000      4000    male       0           1

# %% [markdown]
# ### process original data

# %%
# delete clothes and others
# List of IDs to drop
ids_to_drop = ['ISIC_0573025', 'ISIC_1443812', 'ISIC_5374420', 'ISIC_2611119', 'ISIC_2691718', 'ISIC_9689783', 'ISIC_9520696', 'ISIC_8651165', 'ISIC_9385142', 'ISIC_9680590']
train_meta = train_meta.drop(train_meta[train_meta['isic_id'].isin(ids_to_drop)].index)

# only has lesion_id(strgong label)
train_meta = train_meta[train_meta['lesion_id'].notnull()].reset_index(drop=True)
# add "additional" column
train_meta['additional'] = 0

print(len(train_meta))
print(len(train_meta[train_meta['target']==1]))
print(len(train_meta[train_meta['target']==1]) / len(train_meta) * 100, '%')
display(train_meta.head())
# Out:
# 22053
# 393
# 1.7820704666031832 %
#         isic_id  target  patient_id  age_approx     sex anatom_site_general  \
# 0  ISIC_0015845       0  IP_8170065        60.0    male           head/neck
# 1  ISIC_0073301       0  IP_2536274        40.0  female     posterior torso
# 2  ISIC_0073989       0  IP_1307115        50.0    male     upper extremity
# 3  ISIC_0074611       0  IP_6164902        40.0  female     lower extremity
# 4  ISIC_0075969       0  IP_5117525        40.0  female     posterior torso
#
#    clin_size_long_diam_mm          image_type tbp_tile_type   tbp_lv_A  \
# 0                    1.10  TBP tile: close-up     3D: white  31.712570
# 1                    9.59  TBP tile: close-up        3D: XP  24.237019
# 2                    6.39  TBP tile: close-up     3D: white  19.600317
# 3                    3.31  TBP tile: close-up        3D: XP  18.007100
# 4                    9.05  TBP tile: close-up        3D: XP  21.315824
#
#    tbp_lv_Aext   tbp_lv_B  tbp_lv_Bext   tbp_lv_C  tbp_lv_Cext   tbp_lv_H  \
# 0    25.364740  26.331000    24.549290  41.219030    35.299260  39.702910
# 1    14.291773  28.042227    26.965422  37.064802    30.518663  49.163002
# 2    16.808140  29.830666    31.199751  35.693711    35.439216  56.692980
# 3    10.746140  24.833930    22.160240  30.675390    24.628360  54.054120
# 4     9.534200  30.914309    28.973342  37.550751    30.501730  55.413224
#
#    tbp_lv_Hext   tbp_lv_L  tbp_lv_Lext  tbp_lv_areaMM2  \
# 0    44.064040  48.861520    55.362360        0.919497
# 1    62.076246  46.763747    72.098259       31.975980
# 2    61.687465  56.975435    68.329111       28.617001
# 3    64.129910  35.715100    49.169140        5.948583
# 4    71.785279  46.968562    61.598336       46.162507
#
#    tbp_lv_area_perim_ratio  tbp_lv_color_std_mean  tbp_lv_deltaA  \
# 0                12.235290               0.000000       6.347830
# 1                22.662001               3.947276       9.945246
# 2                18.052941               1.522630       2.792177
# 3                14.665700               1.255051       7.260954
# 4                16.830977               3.170209      11.781624
#
#    tbp_lv_deltaB  tbp_lv_deltaL  tbp_lv_deltaLB  tbp_lv_deltaLBnorm  \
# 0       1.781713      -6.500838        6.839008            4.987244
# 1       1.076805     -25.334512       25.594803           15.996656
# 2      -1.369085     -11.353676       11.614445            7.462467
# 3       2.673692     -13.454040       13.913190           11.708370
# 4       1.940967     -14.629774       14.990645           10.669963
#
#    tbp_lv_eccentricity          tbp_lv_location tbp_lv_location_simple  \
# 0             0.639885              Head & Neck            Head & Neck
# 1             0.900678  Torso Back Middle Third             Torso Back
# 2             0.338695         Left Arm - Upper               Left Arm
# 3             0.771271        Right Leg - Upper              Right Leg
# 4             0.641768  Torso Back Middle Third             Torso Back
#
#    tbp_lv_minorAxisMM  tbp_lv_nevi_confidence  tbp_lv_norm_border  \
# 0            0.821918            1.334303e-07            2.116402
# 1            4.925942            9.964820e+01            2.910906
# 2            5.977840            2.394399e+01            2.187051
# 3            2.127617            9.946209e+01            1.791452
# 4            6.848261            9.902058e+01            1.645372
#
#    tbp_lv_norm_color  tbp_lv_perimeterMM  tbp_lv_radial_color_std_max  \
# 0           0.000000            3.354148                     0.000000
# 1           9.913684           26.919133                     3.215515
# 2           4.998895           22.729299                     1.807261
# 3           3.382435            9.340242                     1.006729
# 4           9.528097           27.874004                     3.187016
#
#    tbp_lv_stdL  tbp_lv_stdLExt  tbp_lv_symm_2axis  tbp_lv_symm_2axis_angle  \
# 0     0.853227        3.912844           0.285714                       55
# 1    11.156617        2.108142           0.144565                      105
# 2     2.590515        2.508804           0.160248                       10
# 3     4.879771        1.308662           0.190184                      140
# 4     4.978959        2.676386           0.117188                      175
#
#      tbp_lv_x     tbp_lv_y    tbp_lv_z  \
# 0   -0.078308  1575.687000   57.174500
# 1  179.450317  1042.495850  180.077301
# 2 -405.034302  1314.600342   65.054626
# 3   74.994020   619.913700    9.337646
# 4   10.673340  1024.758179  154.668274
#
#                                          attribution copyright_license  \
# 0             Memorial Sloan Kettering Cancer Center             CC-BY
# 1  Frazer Institute, The University of Queensland...             CC-BY
# 2             Memorial Sloan Kettering Cancer Center             CC-BY
# 3  Frazer Institute, The University of Queensland...             CC-BY
# 4                                         ACEMID MIA              CC-0
#
#     lesion_id iddx_full  iddx_1 iddx_2 iddx_3 iddx_4 iddx_5 mel_mitotic_index  \
# 0  IL_6727506    Benign  Benign    NaN    NaN    NaN    NaN               NaN
# 1  IL_3854228    Benign  Benign    NaN    NaN    NaN    NaN               NaN
# 2  IL_9898853    Benign  Benign    NaN    NaN    NaN    NaN               NaN
# 3  IL_2988728    Benign  Benign    NaN    NaN    NaN    NaN               NaN
# 4  IL_6219432    Benign  Benign    NaN    NaN    NaN    NaN               NaN
#
#    mel_thick_mm  tbp_lv_dnn_lesion_confidence  additional
# 0           NaN                      3.141455           0
# 1           NaN                     99.886191           0
# 2           NaN                     99.997449           0
# 3           NaN                    100.000000           0
# 4           NaN                     99.999905           0

# %% [markdown]
# ### concat both data

# %%
concatenated = pd.concat([train_meta, train_meta_add], axis=0)
# train_meta = concatenated.reset_index()
# display(train_meta.head())
# display(train_meta.tail())

# %% [markdown]
# # 3. Split to fold

# %%
def split_fold(df:pd.DataFrame):
    # if 'fold' in df.columns:
    #     return df
    
    df['fold'] = -1
    # object
    skf = StratifiedGroupKFold(n_splits=CFG.n_folds, shuffle=True, random_state=CFG.random_seed)

    for i, (train_index, test_index) in enumerate(skf.split(df, df['target'], df['patient_id'])):
        df.loc[test_index, 'fold'] = i
    
    return df
        
train_meta = split_fold(train_meta)
display(train_meta.head().T)

# check
if CFG.view:
    print(train_meta.groupby('fold')['target'].value_counts().head(300))
# Out:
#                                                                    0  \
# isic_id                                                 ISIC_0015845
# target                                                             0
# patient_id                                                IP_8170065
# age_approx                                                      60.0
# sex                                                             male
# anatom_site_general                                        head/neck
# clin_size_long_diam_mm                                           1.1
# image_type                                        TBP tile: close-up
# tbp_tile_type                                              3D: white
# tbp_lv_A                                                    31.71257
# tbp_lv_Aext                                                 25.36474
# tbp_lv_B                                                      26.331
# tbp_lv_Bext                                                 24.54929
# tbp_lv_C                                                    41.21903
# tbp_lv_Cext                                                 35.29926
# tbp_lv_H                                                    39.70291
# tbp_lv_Hext                                                 44.06404
# tbp_lv_L                                                    48.86152
# tbp_lv_Lext                                                 55.36236
# tbp_lv_areaMM2                                              0.919497
# tbp_lv_area_perim_ratio                                     12.23529
# tbp_lv_color_std_mean                                            0.0
# tbp_lv_deltaA                                                6.34783
# tbp_lv_deltaB                                               1.781713
# tbp_lv_deltaL                                              -6.500838
# tbp_lv_deltaLB                                              6.839008
# tbp_lv_deltaLBnorm                                          4.987244
# tbp_lv_eccentricity                                         0.639885
# tbp_lv_location                                          Head & Neck
# tbp_lv_location_simple                                   Head & Neck
# tbp_lv_minorAxisMM                                          0.821918
# tbp_lv_nevi_confidence                                           0.0
# tbp_lv_norm_border                                          2.116402
# tbp_lv_norm_color                                                0.0
# tbp_lv_perimeterMM                                          3.354148
# tbp_lv_radial_color_std_max                                      0.0
# tbp_lv_stdL                                                 0.853227
# tbp_lv_stdLExt                                              3.912844
# tbp_lv_symm_2axis                                           0.285714
# tbp_lv_symm_2axis_angle                                           55
# tbp_lv_x                                                   -0.078308
# tbp_lv_y                                                    1575.687
# tbp_lv_z                                                     57.1745
# attribution                   Memorial Sloan Kettering Cancer Center
# copyright_license                                              CC-BY
# lesion_id                                                 IL_6727506
# iddx_full                                                     Benign
# iddx_1                                                        Benign
# iddx_2                                                           NaN
# iddx_3                                                           NaN
# iddx_4                                                           NaN
# iddx_5                                                           NaN
# mel_mitotic_index                                                NaN
# mel_thick_mm                                                     NaN
# tbp_lv_dnn_lesion_confidence                                3.141455
# additional                                                         0
# fold                                                               2
#
#                                                                               1  \
# isic_id                                                            ISIC_0073301
# target                                                                        0
# patient_id                                                           IP_2536274
# age_approx                                                                 40.0
# sex                                                                      female
# anatom_site_general                                             posterior torso
# clin_size_long_diam_mm                                                     9.59
# image_type                                                   TBP tile: close-up
# tbp_tile_type                                                            3D: XP
# tbp_lv_A                                                              24.237019
# tbp_lv_Aext                                                           14.291773
# tbp_lv_B                                                              28.042227
# tbp_lv_Bext                                                           26.965422
# tbp_lv_C                                                              37.064802
# tbp_lv_Cext                                                           30.518663
# tbp_lv_H                                                              49.163002
# tbp_lv_Hext                                                           62.076246
# tbp_lv_L                                                              46.763747
# tbp_lv_Lext                                                           72.098259
# tbp_lv_areaMM2                                                         31.97598
# tbp_lv_area_perim_ratio                                               22.662001
# tbp_lv_color_std_mean                                                  3.947276
# tbp_lv_deltaA                                                          9.945246
# tbp_lv_deltaB                                                          1.076805
# tbp_lv_deltaL                                                        -25.334512
# tbp_lv_deltaLB                                                        25.594803
# tbp_lv_deltaLBnorm                                                    15.996656
# tbp_lv_eccentricity                                                    0.900678
# tbp_lv_location                                         Torso Back Middle Third
# tbp_lv_location_simple                                               Torso Back
# tbp_lv_minorAxisMM                                                     4.925942
# tbp_lv_nevi_confidence                                                99.648201
# tbp_lv_norm_border                                                     2.910906
# tbp_lv_norm_color                                                      9.913684
# tbp_lv_perimeterMM                                                    26.919133
# tbp_lv_radial_color_std_max                                            3.215515
# tbp_lv_stdL                                                           11.156617
# tbp_lv_stdLExt                                                         2.108142
# tbp_lv_symm_2axis                                                      0.144565
# tbp_lv_symm_2axis_angle                                                     105
# tbp_lv_x                                                             179.450317
# tbp_lv_y                                                             1042.49585
# tbp_lv_z                                                             180.077301
# attribution                   Frazer Institute, The University of Queensland...
# copyright_license                                                         CC-BY
# lesion_id                                                            IL_3854228
# iddx_full                                                                Benign
# iddx_1                                                                   Benign
# iddx_2                                                                      NaN
# iddx_3                                                                      NaN
# iddx_4                                                                      NaN
# iddx_5                                                                      NaN
# mel_mitotic_index                                                           NaN
# mel_thick_mm                                                                NaN
# tbp_lv_dnn_lesion_confidence                                          99.886191
# additional                                                                    0
# fold                                                                          1
#
#                                                                    2  \
# isic_id                                                 ISIC_0073989
# target                                                             0
# patient_id                                                IP_1307115
# age_approx                                                      50.0
# sex                                                             male
# anatom_site_general                                  upper extremity
# clin_size_long_diam_mm                                          6.39
# image_type                                        TBP tile: close-up
# tbp_tile_type                                              3D: white
# tbp_lv_A                                                   19.600317
# tbp_lv_Aext                                                 16.80814
# tbp_lv_B                                                   29.830666
# tbp_lv_Bext                                                31.199751
# tbp_lv_C                                                   35.693711
# tbp_lv_Cext                                                35.439216
# tbp_lv_H                                                    56.69298
# tbp_lv_Hext                                                61.687465
# tbp_lv_L                                                   56.975435
# tbp_lv_Lext                                                68.329111
# tbp_lv_areaMM2                                             28.617001
# tbp_lv_area_perim_ratio                                    18.052941
# tbp_lv_color_std_mean                                        1.52263
# tbp_lv_deltaA                                               2.792177
# tbp_lv_deltaB                                              -1.369085
# tbp_lv_deltaL                                             -11.353676
# tbp_lv_deltaLB                                             11.614445
# tbp_lv_deltaLBnorm                                          7.462467
# tbp_lv_eccentricity                                         0.338695
# tbp_lv_location                                     Left Arm - Upper
# tbp_lv_location_simple                                      Left Arm
# tbp_lv_minorAxisMM                                           5.97784
# tbp_lv_nevi_confidence                                     23.943992
# tbp_lv_norm_border                                          2.187051
# tbp_lv_norm_color                                           4.998895
# tbp_lv_perimeterMM                                         22.729299
# tbp_lv_radial_color_std_max                                 1.807261
# tbp_lv_stdL                                                 2.590515
# tbp_lv_stdLExt                                              2.508804
# tbp_lv_symm_2axis                                           0.160248
# tbp_lv_symm_2axis_angle                                           10
# tbp_lv_x                                                 -405.034302
# tbp_lv_y                                                 1314.600342
# tbp_lv_z                                                   65.054626
# attribution                   Memorial Sloan Kettering Cancer Center
# copyright_license                                              CC-BY
# lesion_id                                                 IL_9898853
# iddx_full                                                     Benign
# iddx_1                                                        Benign
# iddx_2                                                           NaN
# iddx_3                                                           NaN
# iddx_4                                                           NaN
# iddx_5                                                           NaN
# mel_mitotic_index                                                NaN
# mel_thick_mm                                                     NaN
# tbp_lv_dnn_lesion_confidence                               99.997449
# additional                                                         0
# fold                                                               2
#
#                                                                               3  \
# isic_id                                                            ISIC_0074611
# target                                                                        0
# patient_id                                                           IP_6164902
# age_approx                                                                 40.0
# sex                                                                      female
# anatom_site_general                                             lower extremity
# clin_size_long_diam_mm                                                     3.31
# image_type                                                   TBP tile: close-up
# tbp_tile_type                                                            3D: XP
# tbp_lv_A                                                                18.0071
# tbp_lv_Aext                                                            10.74614
# tbp_lv_B                                                               24.83393
# tbp_lv_Bext                                                            22.16024
# tbp_lv_C                                                               30.67539
# tbp_lv_Cext                                                            24.62836
# tbp_lv_H                                                               54.05412
# tbp_lv_Hext                                                            64.12991
# tbp_lv_L                                                                35.7151
# tbp_lv_Lext                                                            49.16914
# tbp_lv_areaMM2                                                         5.948583
# tbp_lv_area_perim_ratio                                                 14.6657
# tbp_lv_color_std_mean                                                  1.255051
# tbp_lv_deltaA                                                          7.260954
# tbp_lv_deltaB                                                          2.673692
# tbp_lv_deltaL                                                         -13.45404
# tbp_lv_deltaLB                                                         13.91319
# tbp_lv_deltaLBnorm                                                     11.70837
# tbp_lv_eccentricity                                                    0.771271
# tbp_lv_location                                               Right Leg - Upper
# tbp_lv_location_simple                                                Right Leg
# tbp_lv_minorAxisMM                                                     2.127617
# tbp_lv_nevi_confidence                                                 99.46209
# tbp_lv_norm_border                                                     1.791452
# tbp_lv_norm_color                                                      3.382435
# tbp_lv_perimeterMM                                                     9.340242
# tbp_lv_radial_color_std_max                                            1.006729
# tbp_lv_stdL                                                            4.879771
# tbp_lv_stdLExt                                                         1.308662
# tbp_lv_symm_2axis                                                      0.190184
# tbp_lv_symm_2axis_angle                                                     140
# tbp_lv_x                                                               74.99402
# tbp_lv_y                                                               619.9137
# tbp_lv_z                                                               9.337646
# attribution                   Frazer Institute, The University of Queensland...
# copyright_license                                                         CC-BY
# lesion_id                                                            IL_2988728
# iddx_full                                                                Benign
# iddx_1                                                                   Benign
# iddx_2                                                                      NaN
# iddx_3                                                                      NaN
# iddx_4                                                                      NaN
# iddx_5                                                                      NaN
# mel_mitotic_index                                                           NaN
# mel_thick_mm                                                                NaN
# tbp_lv_dnn_lesion_confidence                                              100.0
# additional                                                                    0
# fold                                                                          3
#
#                                                     4
# isic_id                                  ISIC_0075969
# target                                              0
# patient_id                                 IP_5117525
# age_approx                                       40.0
# sex                                            female
# anatom_site_general                   posterior torso
# clin_size_long_diam_mm                           9.05
# image_type                         TBP tile: close-up
# tbp_tile_type                                  3D: XP
# tbp_lv_A                                    21.315824
# tbp_lv_Aext                                    9.5342
# tbp_lv_B                                    30.914309
# tbp_lv_Bext                                 28.973342
# tbp_lv_C                                    37.550751
# tbp_lv_Cext                                  30.50173
# tbp_lv_H                                    55.413224
# tbp_lv_Hext                                 71.785279
# tbp_lv_L                                    46.968562
# tbp_lv_Lext                                 61.598336
# tbp_lv_areaMM2                              46.162507
# tbp_lv_area_perim_ratio                     16.830977
# tbp_lv_color_std_mean                        3.170209
# tbp_lv_deltaA                               11.781624
# tbp_lv_deltaB                                1.940967
# tbp_lv_deltaL                              -14.629774
# tbp_lv_deltaLB                              14.990645
# tbp_lv_deltaLBnorm                          10.669963
# tbp_lv_eccentricity                          0.641768
# tbp_lv_location               Torso Back Middle Third
# tbp_lv_location_simple                     Torso Back
# tbp_lv_minorAxisMM                           6.848261
# tbp_lv_nevi_confidence                      99.020582
# tbp_lv_norm_border                           1.645372
# tbp_lv_norm_color                            9.528097
# tbp_lv_perimeterMM                          27.874004
# tbp_lv_radial_color_std_max                  3.187016
# tbp_lv_stdL                                  4.978959
# tbp_lv_stdLExt                               2.676386
# tbp_lv_symm_2axis                            0.117188
# tbp_lv_symm_2axis_angle                           175
# tbp_lv_x                                     10.67334
# tbp_lv_y                                  1024.758179
# tbp_lv_z                                   154.668274
# attribution                                ACEMID MIA
# copyright_license                                CC-0
# lesion_id                                  IL_6219432
# iddx_full                                      Benign
# iddx_1                                         Benign
# iddx_2                                            NaN
# iddx_3                                            NaN
# iddx_4                                            NaN
# iddx_5                                            NaN
# mel_mitotic_index                                 NaN
# mel_thick_mm                                      NaN
# tbp_lv_dnn_lesion_confidence                99.999905
# additional                                          0
# fold                                                3
# fold  target
# 0     0         3685
#       1           75
# 1     0         4661
#       1           71
# 2     0         4478
#       1          111
# 3     0         4282
#       1           68
# 4     0         4554
#       1           68
# Name: count, dtype: int64

# %% [markdown]
# ### OverSampling

# %%
# train_meta_mali = train_meta[train_meta['target']==1]
# for _ in range(100):
#     train_meta = pd.concat([train_meta, train_meta_mali], axis=0)
#     if len(train_meta[train_meta['target']==1]) / len(train_meta) * 100 >= 20:
#         print('over 20% malignant')
#         break

# print(len(train_meta))
# print(len(train_meta[train_meta['target']==1]))
# print(len(train_meta[train_meta['target']==1]) / len(train_meta) * 100, '%')

# if CFG.view:
#     print(train_meta.groupby('fold')['target'].value_counts().head(300))
#     display(train_meta.head())

# %% [markdown]
# # 4. Dataset

# %%
# setting seed in each env
def set_random_seed(seed: int = 42, deterministic: bool = False):
    """Set seeds"""
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # type: ignore
    torch.backends.cudnn.deterministic = deterministic  # type: ignore

# function to set tensor to device
def to_device(
    tensors: tp.Union[tp.Tuple[torch.Tensor], tp.Dict[str, torch.Tensor]],
    device: torch.device, *args, **kwargs
):
    if isinstance(tensors, tuple):
        return (t.to(device, *args, **kwargs) for t in tensors)
    elif isinstance(tensors, dict):
        return {
            k: t.to(device, *args, **kwargs) for k, t in tensors.items()}
    else:
        return tensors.to(device, *args, **kwargs)

# %%
def get_transforms():
    augmentations_train = A.Compose([
    A.Transpose(p=0.5),
    A.VerticalFlip(p=0.5),
    A.HorizontalFlip(p=0.5),
    A.ColorJitter(brightness=0.2, contrast=0.2, p=0.1),
    # A.MotionBlur(blur_limit=5, p=0.1),
    # A.MedianBlur(blur_limit=5, p=0.1),
    # A.GaussianBlur(blur_limit=5, p=0.1),
    # A.GaussNoise(var_limit=(5.0, 30.0), p=0.1),
    # A.OpticalDistortion(distort_limit=0.5, p=0.1),
    # A.GridDistortion(num_steps=5, distort_limit=0.5, p=0.1),
    # A.ElasticTransform(alpha=1, p=0.1),
    # A.CLAHE(clip_limit=2.0, p=0.1),
    # A.HueSaturationValue(hue_shift_limit=5, sat_shift_limit=10, val_shift_limit=5, p=0.1),
    # A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, border_mode=0, p=0.2),
    A.CoarseDropout(max_holes=20, min_holes=10, p=0.2),
    A.Resize(CFG.img_size, CFG.img_size),
    # A.Normalize(
    #                 mean=[0.485, 0.456, 0.406], 
    #                 std=[0.229, 0.224, 0.225], 
    #                 max_pixel_value=255.0, 
    #                 p=1.0
    #             ),
    ToTensorV2(p=1)
    ])
    augmentations_test = A.Compose([
        A.Resize(CFG.img_size, CFG.img_size),
        # A.Normalize(
        #                 mean=[0.485, 0.456, 0.406], 
        #                 std=[0.229, 0.224, 0.225], 
        #                 max_pixel_value=255.0, 
        #                 p=1.0
        #             ),
        ToTensorV2(p=1)
    ])
    return augmentations_train, augmentations_test

# def get_transforms():
#     data_transforms = {
#         "train": A.Compose([
#             A.Resize(CFG.img_size, CFG.img_size),
#             A.RandomRotate90(p=0.5),
#             A.Flip(p=0.5),
#             A.Downscale(p=0.25),
#             A.ShiftScaleRotate(shift_limit=0.1, 
#                             scale_limit=0.15, 
#                             rotate_limit=60, 
#                             p=0.5),
#             A.HueSaturationValue(
#                     hue_shift_limit=0.2, 
#                     sat_shift_limit=0.2, 
#                     val_shift_limit=0.2, 
#                     p=0.5
#                 ),
#             A.RandomBrightnessContrast(
#                     brightness_limit=(-0.1,0.1), 
#                     contrast_limit=(-0.1, 0.1), 
#                     p=0.5
#                 ),
#             A.Normalize(
#                     mean=[0.485, 0.456, 0.406], 
#                     std=[0.229, 0.224, 0.225], 
#                     max_pixel_value=255.0, 
#                     p=1.0
#                 ),
#             ToTensorV2()], p=1.),
        
#         "valid": A.Compose([
#             A.Resize(CFG.img_size, CFG.img_size),
#             A.Normalize(
#                     mean=[0.485, 0.456, 0.406], 
#                     std=[0.229, 0.224, 0.225], 
#                     max_pixel_value=255.0, 
#                     p=1.0
#                 ),
#             ToTensorV2()], p=1.)
#     }
#     return data_transforms["train"], data_transforms["valid"]

# def get_transforms():
#     train_transforms = A.Compose([
#         A.Transpose(p=0.5),
#         A.VerticalFlip(p=0.5),
#         A.HorizontalFlip(p=0.5),
#         A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.75),
#         A.OneOf([
#             A.MotionBlur(blur_limit=5),
#             A.MedianBlur(blur_limit=5),
#             A.GaussianBlur(blur_limit=5),
#             A.GaussNoise(var_limit=(5.0, 30.0)),
#         ], p=0.7),

#         A.OneOf([
#             A.OpticalDistortion(distort_limit=1.0),
#             A.GridDistortion(num_steps=5, distort_limit=1.),
#             A.ElasticTransform(alpha=3),
#         ], p=0.7),

#         A.CLAHE(clip_limit=4.0, p=0.7),
#         A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=20, val_shift_limit=10, p=0.5),
#         A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, border_mode=0, p=0.85),
#         A.Resize(CFG.img_size, CFG.img_size),
#         A.CoarseDropout(max_height=int(CFG.img_size * 0.375), max_width=int(CFG.img_size * 0.375), max_holes=1, min_holes=1, p=0.7),    
#         A.Normalize()
#     ])

#     val_transforms = A.Compose([
#         A.Resize(CFG.img_size, CFG.img_size),
#         A.Normalize()
#     ])

#     return train_transforms, val_transforms

# %%
class ISICDataset(Dataset):
    def __init__(self, 
                 df: pd.DataFrame,
                 fp_hdf: str|Path,
                 transform: A.Compose=None,
                 ):
        self.df = df
        if 'target' in self.df.columns:
            self.is_training = True
            self.targets = df['target'].values
        else:
            self.is_training = False
        self.fp_hdf = h5py.File(fp_hdf, mode="r")
        self.isic_ids = df['isic_id'].values
        self.transform = transform
        
    def __len__(self):
        return len(self.isic_ids)
    
    def __getitem__(self, index):
        isic_id = self.isic_ids[index]
        image = np.array(Image.open(BytesIO(self.fp_hdf[isic_id][()])))
        if self.is_training:
            target = self.targets[index]
        else:
            target = None
        
        if self.transform:
            return (self._apply_transform(image), target)
        else:
            return (image, target)
    
    def _apply_transform(self, img:np.ndarray):
        """apply transform to image"""
        transformed = self.transform(image=img)
        img = transformed["image"]# .float()# .half()
        return img

# %% [markdown]
# # 5. Model

# %%
def F_rgb2hsv(rgb: torch.Tensor) -> torch.Tensor:
    cmax, cmax_idx = torch.max(rgb, dim=1, keepdim=True)
    cmin = torch.min(rgb, dim=1, keepdim=True)[0]
    delta = cmax - cmin
    hsv_h = torch.empty_like(rgb[:, 0:1, :, :])
    cmax_idx[delta == 0] = 3
    hsv_h[cmax_idx == 0] = (((rgb[:, 1:2] - rgb[:, 2:3]) / delta) % 6)[cmax_idx == 0]
    hsv_h[cmax_idx == 1] = (((rgb[:, 2:3] - rgb[:, 0:1]) / delta) + 2)[cmax_idx == 1]
    hsv_h[cmax_idx == 2] = (((rgb[:, 0:1] - rgb[:, 1:2]) / delta) + 4)[cmax_idx == 2]
    hsv_h[cmax_idx == 3] = 0.
    hsv_h /= 6.
    hsv_s = torch.where(cmax == 0, torch.tensor(0.).type_as(rgb), delta / cmax)
    hsv_v = cmax
    return torch.cat([hsv_h, hsv_s, hsv_v], dim=1)


class timmModel(nn.Module):

    def __init__(
            self,
            model_name: str,
            pretrained: bool,
            in_channels: int,
            num_classes: int,
            is_training: bool=False
        ):
        super().__init__()
        self.model = timm.create_model(
            model_name=model_name, 
            pretrained=pretrained, 
            in_chans=in_channels,
            num_classes=num_classes,
            global_pool=''
        )
        self.output_type = ['infer', 'loss']
        self.is_training = is_training

        # model output dim
        dim = CFG.output_dim_models[CFG.model_name]
        
        self.dropout = nn.ModuleList([
			nn.Dropout(0.5) for i in range(5)
		])
        self.target=nn.Linear(dim, 1)
        

    def forward(self, x, target=None):
        batch_size = len(x)
        
        x = torch.cat([x, F_rgb2hsv(x)],1) # (bs, dim, h, w)
        x = self.model(x)    
        # print('model output: ', x.shape)
        pool = F.adaptive_avg_pool2d(x, 1)
        # print('after pooling: ', pool.shape)
        reshaped = pool.reshape(batch_size, -1)  
        # print('after reshape: ', reshaped.shape)
        
        if self.is_training:
            logit = 0
            # print(len(self.dropout))
            for i in range(len(self.dropout)):
                dropped = self.dropout[i](reshaped)
                # print(dropped.shape)
                logit += self.target(dropped)
            logit = logit / len(self.dropout)
        else:
            logit = self.target(reshaped)
            
        output = {}
        if 'loss' in self.output_type:
            if target.dim() == 1:
                target = target.view(-1, 1)
            output['bce_loss'] = F.binary_cross_entropy_with_logits(logit.float(), target.float())

        if 'infer' in self.output_type:
            output['target'] = torch.sigmoid(logit.float())

        return output

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

if CFG.view:
    def show_batch(ds, row=3, col=3, color='rgb'):
        fig = plt.figure(figsize=(10, 10))
        img_index = np.random.randint(0, len(ds)-1, row*col)
        
        for i in range(len(img_index)):
            img, label = ds[img_index[i]]
            img_rgb = img[:3, :, :]
            # img_hsv = img[3:6, :, :]
            
            if color=='rgb':
                img = img_rgb
            # elif color=='hsv':
            #     img = img_hsv
            
            if isinstance(img, torch.Tensor):
                img = img.detach().numpy()
                # Check if the image is in (C, H, W) and transpose it to (H, W, C)
                if img.shape[0] == 3:  # Assuming the image is (C, H, W)
                    img = np.transpose(img, (1, 2, 0))
            
            ax = fig.add_subplot(row, col, i + 1, xticks=[], yticks=[])
            ax.imshow(img)  # Remove cmap parameter for RGB images
            ax.set_title(f'ID: {img_index[i]}; Target: {label}')
        
        plt.tight_layout()
        plt.show()

    _train_transform, _ = get_transforms()
    _dataset = ISICDataset(df=train_meta, fp_hdf=CFG.TRAIN_HDF5, transform=_train_transform)
    show_batch(_dataset)
    # show_batch(_dataset, color='hsv')

# %% [markdown]
# # 6. Training

# %%
# reference
def train_one_fold(val_fold: int, 
                   train: pd.DataFrame,
                   output_path: str|Path
                   ):
    """Main"""
    # If True, forces cuDNN to benchmark multiple convolution algorithms and choose the fastest one
    torch.backends.cudnn.benchmark = True
    set_random_seed(CFG.random_seed, deterministic=CFG.deterministic)
    # set device with pytorch env
    device = torch.device(CFG.device)
    # print(device)
    
    train_transform, val_transform = get_transforms()
    
#     train_dataset = Bird2024Dataset(**train_path_label, transform=train_transform)
    train_dataset = ISICDataset(train[train['fold']!=val_fold], CFG.TRAIN_HDF5, train_transform)
    val_dataset = ISICDataset(train[train['fold']==val_fold], CFG.TRAIN_HDF5, val_transform)
    
    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=CFG.batch_size, num_workers=4, shuffle=True, drop_last=True)
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=CFG.batch_size, num_workers=4, shuffle=False, drop_last=False)
    
    model = timmModel(
        model_name=CFG.model_name, 
        pretrained=CFG.pretrained, 
        num_classes=0, # no classification head
        in_channels=6, # RBG+HSV
        is_training=True
    )
    # transfer learning
    if CFG.PRETRAINED_MODEL:
        model.load_state_dict(torch.load(CFG.PRETRAINED_MODEL, map_location=device))
        
    model = model.to(device)

    
    optimizer = optim.AdamW(params=model.parameters(), lr=CFG.lr, weight_decay=CFG.weight_decay)
    scheduler = lr_scheduler.OneCycleLR(
        optimizer=optimizer, epochs=CFG.max_epoch,
        pct_start=0.0, steps_per_epoch=len(train_loader),
        max_lr=CFG.lr, div_factor=25, final_div_factor=1e4
    )
    
#     loss_func = KLDivLossWithLogits()
    # loss_func = nn.CrossEntropyLoss()
    # loss_func = nn.BCEWithLogitsLoss()
#     loss_func = FocalLossBCE()
    # loss_func.to(device)
#     loss_func_val = KLDivLossWithLogitsForVal()
#     loss_func_val = nn.CrossEntropyLoss()
    # loss_func_val = nn.BCEWithLogitsLoss()
#     loss_func_val = FocalLossBCE()
    
    use_amp = CFG.enable_amp
    scaler = amp.GradScaler(enabled=use_amp)
    
    best_val_loss = 1.0e+09
    best_epoch = 0
    train_loss = 0
    val_loss = 0
    
    for epoch in range(1, CFG.max_epoch + 1):
        epoch_start = time()
        model.train()
        for batch in tqdm(train_loader):
            
            x, t = batch
            x = x.float()/255
            # t = t.float()
#             print(x)
#             print(t)
            x = to_device(x, device)
            t = to_device(t, device)
                
            optimizer.zero_grad()
            with amp.autocast(use_amp):
                output = model(x, t)
                loss = output['bce_loss']
            
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            train_loss += loss.item()
            scheduler.step()
            
        train_loss /= len(train_loader)
            
        model.eval()
        for batch in tqdm(val_loader):
            x, t = batch
            x = x.float()/255
            x = to_device(x, device)
            t = to_device(t, device)
            with torch.no_grad(), amp.autocast(use_amp):
                output = model(x, t)
            loss = output['bce_loss']
            val_loss += loss.item()
        val_loss /= len(val_loader)
        
        if val_loss < best_val_loss:
            best_epoch = epoch
            best_val_loss = val_loss
            # print("save model")
            torch.save(model.state_dict(), str(output_path / f'snapshot_epoch_{epoch}.pth'))
        
        elapsed_time = time() - epoch_start
        print(
            f"[epoch {epoch}] train loss: {train_loss: .6f}, val loss: {val_loss: .6f}, elapsed_time: {elapsed_time: .3f}")
        
        if epoch - best_epoch > CFG.es_patience:
            print("Early Stopping!")
            break
            
        train_loss = 0
        val_loss = 0
            
    return val_fold, best_epoch, best_val_loss

# %% [markdown]
# ### Train

# %%
score_list = []
print('='*20)
print('experiment: ', CFG.exp)
print('='*20)
for fold_id in range(CFG.n_folds):
    output_path = CFG.OUTPUT_DIR / f"fold{fold_id}"
    output_path.mkdir(exist_ok=True)
    print(f"[fold{fold_id}]")
    score_list.append(train_one_fold(fold_id, train_meta, output_path))
# Out:
# ====================
# experiment:  15
# ====================
# [fold0]
# /opt/conda/lib/python3.10/site-packages/torch/cuda/__init__.py:215: UserWarning:
# NVIDIA GeForce RTX 4070 Ti SUPER with CUDA capability sm_89 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_60 sm_70 sm_75 compute_70 compute_75.
# If you want to use the NVIDIA GeForce RTX 4070 Ti SUPER GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(
#   0%|          | 0/142 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# [epoch 1] train loss:  0.085954, val loss:  0.091508, elapsed_time:  38.535
#   0%|          | 0/142 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# [epoch 2] train loss:  0.069088, val loss:  0.091403, elapsed_time:  33.622
#   0%|          | 0/142 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# [epoch 3] train loss:  0.063531, val loss:  0.084407, elapsed_time:  33.594
#   0%|          | 0/142 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# [epoch 4] train loss:  0.060283, val loss:  0.084804, elapsed_time:  33.581
#   0%|          | 0/142 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# [epoch 5] train loss:  0.055924, val loss:  0.083590, elapsed_time:  33.619
#   0%|          | 0/142 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# [epoch 6] train loss:  0.048611, val loss:  0.094016, elapsed_time:  33.517
#   0%|          | 0/142 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# [epoch 7] train loss:  0.041190, val loss:  0.094932, elapsed_time:  33.503
#   0%|          | 0/142 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# [epoch 8] train loss:  0.035320, val loss:  0.098810, elapsed_time:  33.502
#   0%|          | 0/142 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# [epoch 9] train loss:  0.029648, val loss:  0.100677, elapsed_time:  33.577
# [fold1]
#   0%|          | 0/135 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 1] train loss:  0.093088, val loss:  0.067592, elapsed_time:  33.864
#   0%|          | 0/135 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 2] train loss:  0.075448, val loss:  0.065205, elapsed_time:  32.845
#   0%|          | 0/135 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 3] train loss:  0.070764, val loss:  0.060864, elapsed_time:  32.679
#   0%|          | 0/135 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 4] train loss:  0.066883, val loss:  0.062284, elapsed_time:  32.640
#   0%|          | 0/135 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 5] train loss:  0.063359, val loss:  0.058268, elapsed_time:  32.704
#   0%|          | 0/135 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 6] train loss:  0.055666, val loss:  0.060885, elapsed_time:  32.639
#   0%|          | 0/135 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 7] train loss:  0.049511, val loss:  0.058870, elapsed_time:  32.644
#   0%|          | 0/135 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 8] train loss:  0.043591, val loss:  0.063297, elapsed_time:  32.628
#   0%|          | 0/135 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 9] train loss:  0.040236, val loss:  0.063438, elapsed_time:  32.618
# [fold2]
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/36 [00:00<?, ?it/s]
# [epoch 1] train loss:  0.085493, val loss:  0.089377, elapsed_time:  33.901
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/36 [00:00<?, ?it/s]
# [epoch 2] train loss:  0.069173, val loss:  0.100211, elapsed_time:  32.961
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/36 [00:00<?, ?it/s]
# [epoch 3] train loss:  0.066037, val loss:  0.083166, elapsed_time:  32.894
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/36 [00:00<?, ?it/s]
# [epoch 4] train loss:  0.061444, val loss:  0.079498, elapsed_time:  32.894
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/36 [00:00<?, ?it/s]
# [epoch 5] train loss:  0.057177, val loss:  0.079956, elapsed_time:  32.791
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/36 [00:00<?, ?it/s]
# [epoch 6] train loss:  0.051850, val loss:  0.079154, elapsed_time:  32.746
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/36 [00:00<?, ?it/s]
# [epoch 7] train loss:  0.044685, val loss:  0.085109, elapsed_time:  32.750
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/36 [00:00<?, ?it/s]
# [epoch 8] train loss:  0.035939, val loss:  0.092274, elapsed_time:  32.749
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/36 [00:00<?, ?it/s]
# [epoch 9] train loss:  0.031766, val loss:  0.093345, elapsed_time:  32.731
# [fold3]
#   0%|          | 0/138 [00:00<?, ?it/s]
#   0%|          | 0/34 [00:00<?, ?it/s]
# [epoch 1] train loss:  0.090605, val loss:  0.068801, elapsed_time:  34.267
#   0%|          | 0/138 [00:00<?, ?it/s]
#   0%|          | 0/34 [00:00<?, ?it/s]
# [epoch 2] train loss:  0.073790, val loss:  0.063688, elapsed_time:  33.061
#   0%|          | 0/138 [00:00<?, ?it/s]
#   0%|          | 0/34 [00:00<?, ?it/s]
# [epoch 3] train loss:  0.068897, val loss:  0.065446, elapsed_time:  33.070
#   0%|          | 0/138 [00:00<?, ?it/s]
#   0%|          | 0/34 [00:00<?, ?it/s]
# [epoch 4] train loss:  0.065647, val loss:  0.061509, elapsed_time:  33.058
#   0%|          | 0/138 [00:00<?, ?it/s]
#   0%|          | 0/34 [00:00<?, ?it/s]
# [epoch 5] train loss:  0.060270, val loss:  0.059303, elapsed_time:  33.008
#   0%|          | 0/138 [00:00<?, ?it/s]
#   0%|          | 0/34 [00:00<?, ?it/s]
# [epoch 6] train loss:  0.055495, val loss:  0.058244, elapsed_time:  33.037
#   0%|          | 0/138 [00:00<?, ?it/s]
#   0%|          | 0/34 [00:00<?, ?it/s]
# [epoch 7] train loss:  0.047952, val loss:  0.061717, elapsed_time:  32.990
#   0%|          | 0/138 [00:00<?, ?it/s]
#   0%|          | 0/34 [00:00<?, ?it/s]
# [epoch 8] train loss:  0.041650, val loss:  0.065165, elapsed_time:  33.003
#   0%|          | 0/138 [00:00<?, ?it/s]
#   0%|          | 0/34 [00:00<?, ?it/s]
# [epoch 9] train loss:  0.036885, val loss:  0.066093, elapsed_time:  32.910
# [fold4]
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 1] train loss:  0.093476, val loss:  0.070491, elapsed_time:  33.497
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 2] train loss:  0.075161, val loss:  0.063207, elapsed_time:  32.771
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 3] train loss:  0.072828, val loss:  0.061814, elapsed_time:  32.698
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 4] train loss:  0.068862, val loss:  0.058558, elapsed_time:  32.754
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 5] train loss:  0.063487, val loss:  0.058707, elapsed_time:  32.728
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 6] train loss:  0.057842, val loss:  0.060869, elapsed_time:  32.757
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 7] train loss:  0.051434, val loss:  0.063797, elapsed_time:  32.853
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 8] train loss:  0.044763, val loss:  0.062977, elapsed_time:  32.847
#   0%|          | 0/136 [00:00<?, ?it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [epoch 9] train loss:  0.040186, val loss:  0.062005, elapsed_time:  32.765

# %% [markdown]
# # 7. Validation

# %%
print(score_list)
score_list_log = score_list
# Out:
# [(0, 5, 0.08358968381459514), (1, 5, 0.05826849261349117), (2, 6, 0.07915445670692457), (3, 6, 0.05824374692404971), (4, 4, 0.05855817330145353)]

# %%
# select the best model and delete others
best_log_list = []
for (fold_id, best_epoch, _) in score_list:
    
    # select the best model
    exp_dir_path = CFG.OUTPUT_DIR / f"fold{fold_id}"
    best_model_path = exp_dir_path / f"snapshot_epoch_{best_epoch}.pth"
    # copy to new place
    copy_to = CFG.OUTPUT_DIR / f"./best_model_fold{fold_id}.pth"
    shutil.copy(best_model_path, copy_to)
    
    for p in exp_dir_path.glob("*.pth"):
        # delete
        p.unlink()

# %%
# Function for inference
def run_inference_loop(model, loader, device):
    model.to(device)
    model.eval()
    model.output_type = ['infer']
    pred_list = []
    with torch.no_grad():
        for batch in tqdm(loader):
            x = to_device(batch[0], device)
            x = x.float()/255
            output = model(x)
            y = output['target']
            pred_list.append(y.detach().cpu().numpy())
    
    # concatenate to vertical (to df like from long scroll like)
    pred_arr = np.concatenate(pred_list)
    del pred_list
    return pred_arr

# %% [markdown]
# ### Prediction

# %%
# predict for train data with metrix(CV. not test data)


# label_arr = train[CLASSES].values
oof_pred_arr = np.zeros((len(train_meta), CFG.n_classes-1))
score_list = []

for fold_id in range(CFG.n_folds):
    print(f"\n[fold {fold_id}]")
    device = torch.device(CFG.device)

    # get_dataloader
    _, val_transform = get_transforms()
    val_dataset = ISICDataset(df=train_meta[train_meta["fold"] == fold_id], fp_hdf=CFG.TRAIN_HDF5, transform=val_transform)
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=CFG.batch_size, num_workers=4, shuffle=False, drop_last=False)

    # # get model
    model_path = CFG.OUTPUT_DIR / f"best_model_fold{fold_id}.pth"
    model = timmModel(
        model_name=CFG.model_name, 
        pretrained=False, 
        in_channels=6,
        num_classes=0,
        is_training=False
    )
    model.load_state_dict(torch.load(model_path, map_location=device))

    # # inference
    val_pred = run_inference_loop(model, val_loader, device)
    val_idx = train_meta[train_meta["fold"] == fold_id].index.values
    oof_pred_arr[val_idx] = val_pred

    del val_idx
    del model, val_loader
    torch.cuda.empty_cache()
    gc.collect()
# Out:
# [fold 0]
#   0%|          | 0/30 [00:00<?, ?it/s]
# [fold 1]
#   0%|          | 0/37 [00:00<?, ?it/s]
# [fold 2]
#   0%|          | 0/36 [00:00<?, ?it/s]
# [fold 3]
#   0%|          | 0/34 [00:00<?, ?it/s]
# [fold 4]
#   0%|          | 0/37 [00:00<?, ?it/s]

# %% [markdown]
# ### Metrix

# %%
def comp_score(solution: pd.DataFrame, submission: pd.DataFrame, row_id_column_name: str, min_tpr: float=0.80):
    v_gt = abs(np.asarray(solution.values)-1)
    v_pred = np.array([1.0 - x for x in submission.values])
    max_fpr = abs(1-min_tpr)
    partial_auc_scaled = roc_auc_score(v_gt, v_pred, max_fpr=max_fpr)
    # change scale from [0.5, 1.0] to [0.5 * max_fpr**2, max_fpr]
    # https://math.stackexchange.com/questions/914823/shift-numbers-into-a-different-range
    partial_auc = 0.5 * max_fpr**2 + (max_fpr - 0.5 * max_fpr**2) / (1.0 - 0.5) * (partial_auc_scaled - 0.5)
    return partial_auc

# %%
# make true array
label_arr = train_meta['target']
# one-hot
# ture_arr = np.zeros((label_arr.size, CFG.n_classes))
# ture_arr[np.arange(label_arr.size), label_arr] = 1
ture_arr = pd.DataFrame(label_arr)

# oof
oof = pd.DataFrame(oof_pred_arr)

micro_roc_auc_ovr = comp_score(
    ture_arr,
    oof,
    ""
)

print(f"CV: Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.10f}")
# Out:
# CV: Micro-averaged One-vs-Rest ROC AUC score:
# 0.1266205691

# %%
with open(CFG.OUTPUT_LOG, 'a') as f:
    f.write('\n')
    f.write(str(score_list_log))
    f.write('\n')
    f.write(f"CV: Micro-averaged One-vs-Rest ROC AUC score: {micro_roc_auc_ovr:.10f}")

# %%
display(oof.head())
display(ture_arr.head())
display(oof.tail())
display(ture_arr.tail())
# Out:
#           0
# 0  0.041698
# 1  0.000892
# 2  0.007667
# 3  0.000489
# 4  0.001192
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#               0
# 22048  0.002878
# 22049  0.001321
# 22050  0.001526
# 22051  0.003545
# 22052  0.003914
#        target
# 22048       0
# 22049       0
# 22050       0
# 22051       0
# 22052       0
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
